# %%
# change this comment so we know when we uploaded the data last
# !wget https://www.dropbox.com/s/xq4vosn9xyn1dy1/grouped_data.pickle?dl=0 -O grouped_data.pickle

# %%
# download the partially trained gpt model (20% checkpoint)
# !wget https://www.dropbox.com/sh/hxlnbb077rghqis/AACUvbPMzaUK-SVal3raSuowa?dl=0 -O gpt_model_partially_trained.zip
# !unzip -o gpt_model_partially_trained.zip -d gpt_model_partially_trained
# Out:
# --2021-05-05 19:16:58--  https://www.dropbox.com/sh/hxlnbb077rghqis/AACUvbPMzaUK-SVal3raSuowa?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /sh/raw/hxlnbb077rghqis/AACUvbPMzaUK-SVal3raSuowa [following]
# --2021-05-05 19:16:58--  https://www.dropbox.com/sh/raw/hxlnbb077rghqis/AACUvbPMzaUK-SVal3raSuowa
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucef02e1d1bb1588408fbba4897c.dl.dropboxusercontent.com/zip_download_get/AxX6E3n0wXgzLR4JLYDhwj2vz6t3MJ78YSF7Zk6XXOifk4q9HVreW8cLNYt1Kg-5NXBGW2uX7LOpzILSnPbXKq5Uu0ow0GVkLdCGqKOhf42ATg [following]
# ...

# %%
# download the finished gpt model
# !wget https://www.dropbox.com/sh/quejv8g67twlnbp/AACt1PCruexhmOuDK_lGgsiba?dl=0 -O gpt_model.zip
# !unzip -o gpt_model.zip -d gpt_model
# Out:
# --2021-05-05 19:17:32--  https://www.dropbox.com/sh/quejv8g67twlnbp/AACt1PCruexhmOuDK_lGgsiba?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /sh/raw/quejv8g67twlnbp/AACt1PCruexhmOuDK_lGgsiba [following]
# --2021-05-05 19:17:32--  https://www.dropbox.com/sh/raw/quejv8g67twlnbp/AACt1PCruexhmOuDK_lGgsiba
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc870ddef75a0c703593dcd724b0.dl.dropboxusercontent.com/zip_download_get/AxVnbabwRb53t0I9dFTeMdvaYYP9mUvVaQ4H4dWdy2nEpSVrAf-G6jcOtDksXFRKTc49Ufd-BbnASXKfWQbxSTsWy03F8PrCBsNu0ESl7yr1Gw [following]
# ...

# %%
# download the upvote predictor model
# !wget https://www.dropbox.com/sh/3yzyslhzxjm0zvo/AABhPDg-0dQCT2mSAg5JskXqa?dl=0 -O upvote_model_finished.zip
# !unzip -o upvote_model_finished.zip -d upvote_model_finished
# Out:
# --2021-05-05 19:18:06--  https://www.dropbox.com/sh/3yzyslhzxjm0zvo/AABhPDg-0dQCT2mSAg5JskXqa?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /sh/raw/3yzyslhzxjm0zvo/AABhPDg-0dQCT2mSAg5JskXqa [following]
# --2021-05-05 19:18:06--  https://www.dropbox.com/sh/raw/3yzyslhzxjm0zvo/AABhPDg-0dQCT2mSAg5JskXqa
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc0d50d1b7febe6dfc5ea5175811.dl.dropboxusercontent.com/zip_download_get/AxWPfXmWEor1usDwFwlZH-kvWWfsV3skFvQK3YBrAJ3zoDsenU_zIVZx9n5bgEkjBiqoNxGiNbSvSCtOoWPqtTm8ZdLSQCUGCkupRdJ8ekBE-g [following]
# ...

# %%
# download the finished realism detector model
# !wget https://www.dropbox.com/sh/6jcz8q6yv7pxvrb/AACoZAVEJPnaN4J-biYLPVxia?dl=0 -O realism_model_finished.zip
# !unzip -o realism_model_finished.zip -d realism_model_finished
# Out:
# --2021-05-05 19:18:36--  https://www.dropbox.com/sh/6jcz8q6yv7pxvrb/AACoZAVEJPnaN4J-biYLPVxia?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /sh/raw/6jcz8q6yv7pxvrb/AACoZAVEJPnaN4J-biYLPVxia [following]
# --2021-05-05 19:18:36--  https://www.dropbox.com/sh/raw/6jcz8q6yv7pxvrb/AACoZAVEJPnaN4J-biYLPVxia
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc34464a39cefa81cfab28018011.dl.dropboxusercontent.com/zip_download_get/AxX2742NOq0J-TCyxx2zT9NCvVen52xkNlC7A4dDdS-lkhL3zpvJ11UFqSoznAjXPKClkSYjH2QjcBw7Yd98v42WV5TzutY3uhjSJVQbcTiUfA [following]
# ...

# %%
# # download the realism detector model
# !wget https://drive.google.com/drive/folders/1adhWS2tfJQF8PHM6_ZkEvwOGEPVTrC4M?usp=sharing -O realism_model_finished.zip
# !unzip -o realism_model_finished.zip -d realism_model_finished

# %%
# !pip install transformers
# !pip install -U sentence-transformers
import pickle
import pandas as pd
import random
import torch
import warnings
import re
import string
import numpy as np
import spacy
warnings.filterwarnings("ignore")

from sentence_transformers import SentenceTransformer
from scipy.spatial import distance

from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn import metrics
from transformers import AutoTokenizer
from transformers import TextDataset, DataCollatorForLanguageModeling
from transformers import Trainer, TrainingArguments, AutoModelWithLMHead
from transformers import BertForSequenceClassification, BertTokenizerFast, Trainer, TrainingArguments
from transformers import pipeline
from transformers import GPT2ForSequenceClassification, GPT2Tokenizer
from google.colab import drive
from joblib import dump, load


random.seed(2021)
drive.mount('/content/gdrive')
# Out:
# ...
#      |████████████████████████████████| 2.1MB 12.0MB/s
# ...
#      |████████████████████████████████| 901kB 62.7MB/s
# ...
#      |████████████████████████████████| 3.3MB 60.9MB/s
# ...
#      |████████████████████████████████| 81kB 6.1MB/s
# ...
#      |████████████████████████████████| 1.2MB 20.1MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-1.1.0-cp37-none-any.whl size=119615 sha256=2bb7ba75cd93cba1198c0ae6269c80dabfd4d4bd91b1ba32b05df1c8945c3c6e
#   Stored in directory: /root/.cache/pip/wheels/84/cb/21/1066bff3027215c760ca14a198f698bca8fccb92e33e2327eb
# Successfully built sentence-transformers
# ...
# Mounted at /content/gdrive

# %%
class Net(torch.nn.Module):
    def __init__(self, input_size):
        super(Net, self).__init__()                    # Inherited from the parent class nn.Module
        self.fc1 = torch.nn.Linear(input_size, 250)  
        self.relu = torch.nn.ReLU()                        
        self.fc2 = torch.nn.Linear(250, 50) 
        self.relu2 = torch.nn.ReLU()    
        self.fc3 = torch.nn.Linear(50, 2) 
        self.softmax = torch.nn.Softmax(dim=1) 
    def forward(self, x):                              # Forward pass: stacking each layer together
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.relu2(out)
        out = self.fc3(out)
        out = self.softmax(out)
        return out

# %%
class CasualConversationBot:
    def __init__(self, sep_token='<SEP>', eos_token='<EOS>', realism_threshold=0.95, relevance_threshold=0.95): 
        # gpt model
        self.gpt_model_pipeline = pipeline('text-generation', model='./gpt_model', tokenizer='gpt2', config={'max_length':2500})
        # self.gpt_model_pipeline = pipeline('text-generation', model='gpt2', tokenizer='gpt2', config={'max_length':2500})
        
        # upvote predictor model
        # self.upvote_predictor = BertForSequenceClassification.from_pretrained('upvote_model_finished', num_labels=2)
        # self.upvote_predictor_tokenizer = BertTokenizerFast.from_pretrained('distilbert-base-cased', use_cache=True)

        # sim model
        self.simmodel = SentenceTransformer('stsb-mpnet-base-v2')

        # relevance model
        # self.relevance_model = GPT2ForSequenceClassification.from_pretrained('/content/gdrive/My Drive/relevance_model_gpt', num_labels=2)
        # self.relevance_model_tokenizer = GPT2Tokenizer.from_pretrained('gpt2', use_cache=True)
        # self.relevance_model_tokenizer.pad_token =  self.relevance_model_tokenizer.eos_token
        
        # realism discriminator model
        self.realism_model = BertForSequenceClassification.from_pretrained('realism_model_finished', num_labels=2)
        self.realism_model_tokenizer = BertTokenizerFast.from_pretrained('distilbert-base-cased', use_cache=True)
        self.realism_threshold = realism_threshold
        
        # parameters
        self.sep_token = sep_token
        self.eos_token = eos_token

        # nlp
        self.nlp = spacy.load('en_core_web_sm') # Load the English Model

        # roberta
        self.relevance_model_lm = SentenceTransformer('stsb-distilroberta-base-v2')
        self.relevance_model = Net(768)
        self.relevance_model.load_state_dict(torch.load('/content/gdrive/My Drive/relevancy_model_v2'))
        self.relevance_model.eval()
        self.relevance_threshold = relevance_threshold 
  
    def clean(self, s):
      s = s.strip()
      s = re.sub(' +', ' ', s)
      s = re.sub('\n+', ' ', s)
      doc = self.nlp(s)

      if str(list(doc.sents)[-1]).strip()[-1] in string.punctuation.replace('?','').replace(',',''):
        return s
      
      return ' '.join([str(x) for x in list(doc.sents)[:-1]])

    def check_valid(self, s):
      if 'BOS' in s or 'EOS' in s:
        return False
      if len(s) == 0:
        return False
      return True
        

    def generate_gpt_responses(self, question, num_candidates=5):
        questions = []
        responses = []
        for _ in range(num_candidates):
            text = self.gpt_model_pipeline(question + " " + self.sep_token)[0]['generated_text'].split(self.sep_token,1)
            questions.append(text[0])
            responses.append(text[1].split(self.eos_token, 1)[0])
        return questions, responses
    
    def tokenize_responses(self, responses, tokenizer, questions=None):

        if questions != None:
          encodings = tokenizer(text=questions, text_pair=responses, truncation=True, padding=True)
        else:
          encodings = tokenizer(text=responses, truncation=True, padding=True)

        items = {key: torch.tensor(val) for key, val in encodings.items()}

        return items
    
    def score_responses(self, responses, model, tokenizer, questions=None):
        items = self.tokenize_responses(responses=responses, tokenizer=tokenizer, questions=questions)

        if 'token_type_ids' in items.keys():
          outs = model.forward(input_ids=items['input_ids'], attention_mask=items['attention_mask'], token_type_ids=items['token_type_ids'])
        else:
          outs = model.forward(input_ids=items['input_ids'], attention_mask=items['attention_mask'])
        probs = torch.softmax(outs.logits, 1)
        return probs

    

    def predict(self, question, num_candidates=5):
        # generate possible candidate responses from gpt model based on questions
        questions = []
        responses = []
        while len(responses) < num_candidates:
          q, r = self.generate_gpt_responses(question=question, num_candidates=1)
          r = self.clean(r[0])
          realism_scores = self.score_responses(responses=[r], model=self.realism_model, tokenizer=self.realism_model_tokenizer)

          eval_pairs = [q[0] + " " + r]
          embed_eval = self.relevance_model_lm.encode(eval_pairs)
          relevance_scores = self.relevance_model.forward(torch.as_tensor(embed_eval))

          # if self.check_valid(r) and realism_scores[0][1] > self.realism_threshold:
          if self.check_valid(r) and realism_scores[0][1] > self.realism_threshold and relevance_scores[0][0] > self.relevance_threshold:
            questions.append(q[0])
            responses.append(r)

            print('%d\%d\n' % (len(responses), num_candidates))

        # sim scores

        response_embeddings = self.simmodel.encode(responses)
        post_embedding = self.simmodel.encode(questions)
        cosine_similarites = []
        for response, embedding in zip(responses, response_embeddings):
            cosine_similarites.append(distance.cosine(post_embedding[0], embedding))
        sim_scores = torch.softmax(1/torch.Tensor(cosine_similarites), dim=0)

        # relevancy model
        
        eval_pairs = [questions[i] + " " + responses[i] for i in range(len(responses))]
        embed_eval = self.relevance_model_lm.encode(eval_pairs)
        relevance_scores = self.relevance_model.forward(torch.as_tensor(embed_eval))

        # relevance_scores = self.score_responses(questions=questions, responses=responses, model=self.relevance_model, tokenizer=self.relevance_model_tokenizer)

        # get upvote predictions based on responses
        # upvote_scores = self.score_responses(questions=questions, responses=responses, model=self.upvote_predictor, tokenizer=self.upvote_predictor_tokenizer)

        # get realism discriminator scores
        realism_scores = self.score_responses(responses=responses, model=self.realism_model, tokenizer=self.realism_model_tokenizer)
        
        # find best response based on upvote predictor 
        scores = []

        for idx in range(len(responses)):
            print(responses[idx])
            print('Realism score: ', realism_scores[idx])
            print('Relevance score: ', relevance_scores[idx])
            print('Sim score: ', sim_scores[idx])

            # scores.append((relevance_scores[idx][0] + sim_scores[idx]).cpu().detach().numpy())
            scores.append(relevance_scores[idx][0] * realism_scores[idx][1])

            print('Score: ', scores[idx])
            print('------------')

        
        scores = np.array(scores)
        idx = scores.argmax()

        print('='*25, '\n', responses[idx], scores[idx])

# %%
bot = CasualConversationBot(sep_token='<BOS>')
# bot.predict(question="How was your day?")

# %%
bot.predict(question="I ate a bunch of potatoes.", num_candidates=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 1\5
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 2\5
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
bot.predict(question="What is your name?", num_candidates=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
bot.predict(question="How was your day, Reddit?", num_candidates=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
with open('/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'

# %%
bot.predict(question="I showed up late for work yesterday and everyone was genuinely happy to see me.", num_candidates=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 1\5
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
bot.predict(question="After a year without Instagram or Facebook, I’m shocked that I ever shared personal details of my day with hundreds of people.", num_candidates=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 1\5
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
bot.predict(question="Is it bad to visit our parents way to often?", num_candidates=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
bot.predict(question="I asked for a raise and I got it.", num_candidates=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
bot.predict(question="I just had a fresh mango for the first time in my life.", num_candidates=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 1\5
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
bot.predict(question="As of this morning I am a published author!", num_candidates=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
bot.predict(question="Ate a banana with the peel.", num_candidates=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
bot.predict(question="An old friend committed suicide yesterday.", num_candidates=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
bot.predict(question="Is anyone else going to continue to wear a mask after the mandate is lifted?", num_candidates=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...
